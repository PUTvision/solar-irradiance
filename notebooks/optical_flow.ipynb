# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# from skimage.registration import optical_flow_tvl1, optical_flow_ilk

# %%
img_path_1 = './20160202_03/20160202_001559.jpg'
img_path_2 = './20160202_03/20160202_002059.jpg'

img1 = cv2.cvtColor(cv2.imread(img_path_1), cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(cv2.imread(img_path_2), cv2.COLOR_BGR2RGB)

img1_grey = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
img2_grey = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4))

ax[0].imshow(img1)
ax[1].imshow(img2)

# %% [markdown]
# ### Lucas-Kanade (iLK) solver

# %%
flow = optical_flow_ilk(moving_image=img2_grey, reference_image=img1_grey)

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[0], cmap='bwr')
ax[2].imshow(flow[1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ### TV-L1 solver

# %%
flow = optical_flow_tvl1(moving_image=img2_grey, reference_image=img1_grey)

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[0], cmap='bwr')
ax[2].imshow(flow[1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ### Farneback Optical Flow

# %%
flow = cv2.calcOpticalFlowFarneback(img1_grey, img2_grey, None, 0.5, 3, 15, 3, 5, 1.2, 0)

# farneback_of = cv2.optflow.createOptFlow_Farneback()
# flow = farneback_of.calc(img1_grey, img2_grey, None)

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[..., 0], cmap='bwr')
ax[2].imshow(flow[..., 1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ### DIS Optical Flow

# %%
flow[..., 0].min(), flow[..., 0].max()
# Out:
# (-150.7349, 24.29299)

# %%
flow[..., 0][:10, :10]
# Out:
# array([[3.732326 , 3.732326 , 3.7342157, 3.7379947, 3.741774 , 3.7455533,
#         3.7511764, 3.758644 , 3.7661119, 3.7735791],
#        [3.7323263, 3.7323263, 3.7342157, 3.737995 , 3.741774 , 3.7455533,
#         3.7511766, 3.758644 , 3.7661116, 3.7735791],
#        [3.7300334, 3.7300334, 3.7319634, 3.735823 , 3.7396827, 3.7435422,
#         3.7492554, 3.756822 , 3.764389 , 3.7719557],
#        [3.7254477, 3.7254477, 3.727458 , 3.7314787, 3.7354994, 3.73952  ,
#         3.7454128, 3.7531784, 3.7609437, 3.7687087],
#        [3.7208624, 3.7208624, 3.7229528, 3.7271347, 3.7313166, 3.735498 ,
#         3.7415705, 3.7495344, 3.7574983, 3.765462 ],
#        [3.7162766, 3.7162766, 3.7184477, 3.7227907, 3.7271333, 3.7314758,
#         3.7377284, 3.7458906, 3.7540529, 3.762215 ],
#        [3.7095013, 3.7095013, 3.7112641, 3.7147903, 3.7183163, 3.721842 ,
#         3.7274427, 3.735118 , 3.742793 , 3.7504683],
#        [3.700536 , 3.700536 , 3.7014017, 3.7031336, 3.7048652, 3.7065966,
# ...

# %%
dis_of = cv2.DISOpticalFlow_create(preset=cv2.DISOPTICAL_FLOW_PRESET_FAST)

flow = dis_of.calc(img1_grey, img2_grey, None)

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[..., 0], cmap='bwr')
ax[2].imshow(flow[..., 1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ### DeepFlow Optical Flow

# %%
deep_flow_of = cv2.optflow.createOptFlow_DeepFlow()

flow = deep_flow_of.calc(img1_grey, img2_grey, None)

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[..., 0], cmap='bwr')
ax[2].imshow(flow[..., 1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ### SimpleFlow Optical Flow

# %%
simple_flow_of = cv2.optflow.createOptFlow_SimpleFlow()

flow = simple_flow_of.calc(img1_grey, img2_grey, None)

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[..., 0], cmap='bwr')
ax[2].imshow(flow[..., 1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ### PCAFlow Optical Flow

# %%
pca_of = cv2.optflow.createOptFlow_PCAFlow()

flow = pca_of.calc(img1_grey, img2_grey, None)

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[..., 0], cmap='bwr')
ax[2].imshow(flow[..., 1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ### DualTVL1 Optical Flow

# %%
dual_tvl1_of = cv2.optflow.createOptFlow_DualTVL1()

flow = dual_tvl1_of.calc(img1_grey, img2_grey, None)

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[..., 0], cmap='bwr')
ax[2].imshow(flow[..., 1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ### DenseRLOF Optical Flow

# %%
dense_rlof = cv2.optflow.createOptFlow_DenseRLOF()

flow = dense_rlof.calc(img1, img2, None)

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[..., 0], cmap='bwr')
ax[2].imshow(flow[..., 1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ### Variational Refinement

# %%
var_ref = cv2.VariationalRefinement.create()

flow = var_ref.calc(img1_grey, img2_grey, np.zeros((*img1_grey.shape, 2), dtype=np.float32))

fig, ax = plt.subplots(1, 4, figsize=(16, 4))

ax[0].imshow(img1)
ax[1].imshow(flow[..., 0], cmap='bwr')
ax[2].imshow(flow[..., 1], cmap='bwr')
ax[3].imshow(img2)

# %% [markdown]
# ## CUDA Optical Flow
#
# OpenCV build in version 4.8.0, with below cmake configuration:
#
# ```shell
# cmake -D CMAKE_BUILD_TYPE=RELEASE -D CMAKE_INSTALL_PREFIX=/usr/local -D WITH_TBB=ON -D ENABLE_FAST_MATH=1 -D CUDA_FAST_MATH=1 -D WITH_CUBLAS=1 -D WITH_CUDA=ON -D BUILD_opencv_cudacodec=OFF -D WITH_CUDNN=ON -D OPENCV_DNN_CUDA=ON -D CUDA_ARCH_BIN=7.5 -D CUDA_ARCH_PTX=7.5 -D WITH_V4L=ON -D WITH_QT=OFF -D WITH_OPENGL=ON -D WITH_GSTREAMER=ON -D OPENCV_GENERATE_PKGCONFIG=ON -D OPENCV_PC_FILE_NAME=opencv.pc -D OPENCV_ENABLE_NONFREE=ON -D BUILD_opencv_python3=ON -D OPENCV_EXTRA_MODULES_PATH=~/bin/opencv_contrib-4.8.0/modules -D INSTALL_PYTHON_EXAMPLES=ON -D INSTALL_C_EXAMPLES=OFF -D BUILD_EXAMPLES=OFF -D BUILD_opencv_python2=OFF -D BUILD_opencv_java=OFF -D BUILD_opencv_python=OFF ..
# ```

# %%
print(f'CUDA enabled devices: {cv2.cuda.getCudaEnabledDeviceCount()}')

gpu_prev = cv2.cuda_GpuMat()
gpu_prev.upload((img1_grey  / 255.).astype(np.float32))

gpu_frame = cv2.cuda_GpuMat()
gpu_frame.upload((img2_grey  / 255.).astype(np.float32))

print(f'Empty frames? : {gpu_frame.empty()}, {gpu_prev.empty()}')
# Out:
# CUDA enabled devices: 1
# Empty frames? : False, False

# %% [markdown]
# ### Brox Optical Flow

# %%
brox_of = cv2.cuda_BroxOpticalFlow.create(
    alpha=0.197, gamma=50.0, scale_factor=0.8, inner_iterations=10, outer_iterations=77, solver_iterations=10
)

gpu_flow = brox_of.calc(gpu_prev, gpu_frame, None)

gpu_flow_x = cv2.cuda_GpuMat(gpu_flow.size(), cv2.CV_32FC1)
gpu_flow_y = cv2.cuda_GpuMat(gpu_flow.size(), cv2.CV_32FC1)
cv2.cuda.split(gpu_flow, [gpu_flow_x, gpu_flow_y], cv2.cuda.Stream_Null())

flow_x = gpu_flow_x.download()
flow_y = gpu_flow_y.download()

gpu_magnitude, gpu_angle = cv2.cuda.cartToPolar(gpu_flow_x, gpu_flow_y, angleInDegrees=False)
gpu_v = cv2.cuda.normalize(gpu_magnitude, 0.0, 255.0, cv2.NORM_MINMAX, -1)

res = gpu_v.download()

fig, ax = plt.subplots(1, 5, figsize=(20, 4))

ax[0].imshow(img1)
ax[1].imshow(flow_x, cmap='bwr')
ax[2].imshow(flow_y, cmap='bwr')
ax[3].imshow(res, cmap='bwr')
ax[4].imshow(img2)
